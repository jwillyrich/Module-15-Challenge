# %%
import pandas as pd
import os
from datetime import datetime

# %%
# 1. Create a DataFrame for the 201908-citibike-tripdata data. 
# citibike_dataset = os.path.join('C:Users>jwill>Desktop>AnalysisProjects>Module 15 Challenge>201908-citibike-tripdata.csv')
citibike_df = pd.read_csv("./Resources/201908-citibike-tripdata.csv")
citibike_df.sample(10)
# Out:
#         tripduration starttime stoptime  start station id  \
# 624562           573   50:27.4  00:01.4             359.0
# 774832           898   43:59.8  58:58.4             426.0
# 21629            667   53:41.6  04:49.0             416.0
# 268523          1048   00:20.3  17:49.2             164.0
# 779076           412   21:49.1  28:41.4             505.0
# 243721           239   58:54.8  02:53.9             362.0
# 961144          1140   29:46.1  48:46.2             408.0
# 785172          1055   34:51.8  52:27.5             474.0
# 864342           907   19:11.4  34:18.8             523.0
# 280756           872   13:19.5  27:51.8             285.0
#
#                    start station name  start station latitude  \
# 624562             E 47 St & Park Ave               40.755103
# 774832          West St & Chambers St               40.717548
# 21629   Cumberland St & Lafayette Ave               40.687534
# 268523                E 47 St & 2 Ave               40.753231
# ...

# %%
# 2. Check the datatypes of your columns. 
citibike_df.dtypes
# Out:
# tripduration                 int64
# starttime                   object
# stoptime                    object
# start station id           float64
# start station name          object
# start station latitude     float64
# start station longitude    float64
# end station id             float64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                    object
# birth year                   int64
# gender                       int64
# dtype: object

# %%
# 3. Convert the 'tripduration' column to datetime datatype.
citibike_df['tripduration'] = pd.to_datetime(citibike_df['tripduration'], unit='s')

# %%
# 4. Check the datatypes of your columns. 
citibike_df.dtypes
# Out:
# tripduration               datetime64[ns]
# starttime                          object
# stoptime                           object
# start station id                  float64
# start station name                 object
# start station latitude            float64
# start station longitude           float64
# end station id                    float64
# end station name                   object
# end station latitude              float64
# end station longitude             float64
# bikeid                              int64
# usertype                           object
# birth year                          int64
# gender                              int64
# dtype: object

# %%
# View sample of the updated DF
citibike_df.sample(10)
# Out:
#               tripduration starttime stoptime  start station id  \
# 38636  1970-01-01 00:21:02   52:05.1  13:07.7             415.0
# 658892 1970-01-01 00:13:11   36:46.8  49:58.5             351.0
# 111619 1970-01-01 00:12:30   01:07.2  13:37.7             259.0
# 647678 1970-01-01 00:22:49   17:25.1  40:14.4             161.0
# 377906 1970-01-01 00:21:00   50:16.7  11:17.6             462.0
# 173937 1970-01-01 00:38:00   54:49.0  32:49.7             217.0
# 803762 1970-01-01 00:07:14   08:16.7  15:31.2            3602.0
# 898287 1970-01-01 00:08:35   37:40.8  46:16.3             342.0
# 294290 1970-01-01 00:32:34   37:02.7  09:37.2             405.0
# 86629  1970-01-01 00:22:01   18:44.0  40:45.6            3110.0
#
#                    start station name  start station latitude  \
# 38636       Pearl St & Hanover Square               40.704718
# 658892           Front St & Maiden Ln               40.705310
# 111619        South St & Whitehall St               40.701221
# ...

# %%
# 5. Export the Dataframe as a new CSV file without the index.
output_data_filename = "NYC_CityBike_data_cleaned.csv"
citibike_df.to_csv(output_data_filename, index=False)
